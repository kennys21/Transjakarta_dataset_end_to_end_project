# %%
#Reading the csv file from the raw volume
df = spark.read.csv("/Volumes/transjakarta_dataset/raw/dataset/dfTransjakarta.csv", header=True, inferSchema=True)
display(df)

# %%
#Writing the df as delta and save it as a table and put it into the bronze schema
df.write.format("delta").mode("overwrite").saveAsTable("transjakarta_dataset.bronze.transjakarta_raw")
